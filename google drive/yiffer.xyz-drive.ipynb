# %% [markdown]
# ### Mount Google Drive
# To stream files we need to mount Google Drive.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# install dependancies

# %%
# !python -m pip install requests
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests) (3.0.4)

# %% [markdown]
# ## link to ur porn

# %%
yiffLink = input("Paste yo shit \n")
# Out:
# Paste yo shit
# https://yiffer.xyz/First%20Class%20Entertainment

# %% [markdown]
# ## path you want your porn in drive

# %%
path = "/content/drive/Shared drives/Unlimited Drive/funny media/comics/My own collection/sea salt/first class entertainment/"

# %%
from tokenize import Imagnumber
import os
import requests
import shutil # used to save file

comicName = yiffLink.split("/")[-1]
staticYiffLink = "https://static.yiffer.xyz/comics"


for i in range(1,999):
  fileName = str(i)
  length = len(fileName)
  if length == 1:
    fileName = '0'+'0'+ fileName
  elif length == 2:
    fileName = '0' + fileName
  elif length == 0: break
  fileName += '.jpg'


  print(staticYiffLink + '/' + comicName + '/' + fileName)
  imageBuffer = requests.get((staticYiffLink + '/' + comicName + '/' + fileName), stream = True)
  imageBuffer.raw.decode_content = True
  if imageBuffer.status_code == 200:
    with open(path + fileName,'wb') as f:
      shutil.copyfileobj(imageBuffer.raw, f)
    print("done downloading ", testint)
  if imageBuffer.status_code == 404:
    break
  

print("execution complete")
# Out:
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/001.jpg
# done downloading  1
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/002.jpg
# done downloading  2
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/003.jpg
# done downloading  3
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/004.jpg
# done downloading  4
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/005.jpg
# done downloading  5
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/006.jpg
# done downloading  6
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/007.jpg
# done downloading  7
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/008.jpg
# done downloading  8
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/009.jpg
# done downloading  9
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/010.jpg
# done downloading  10
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/011.jpg
# done downloading  11
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/012.jpg
# done downloading  12
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/013.jpg
# done downloading  13
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/014.jpg
# done downloading  14
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/015.jpg
# done downloading  15
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/016.jpg
# done downloading  16
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/017.jpg
# done downloading  17
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/018.jpg
# done downloading  18
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/019.jpg
# done downloading  19
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/020.jpg
# done downloading  20
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/021.jpg
# done downloading  21
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/022.jpg
# done downloading  22
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/023.jpg
# done downloading  23
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/024.jpg
# done downloading  24
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/025.jpg
# done downloading  25
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/026.jpg
# done downloading  26
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/027.jpg
# done downloading  27
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/028.jpg
# done downloading  28
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/029.jpg
# done downloading  29
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/030.jpg
# done downloading  30
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/031.jpg
# done downloading  31
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/032.jpg
# done downloading  32
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/033.jpg
# done downloading  33
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/034.jpg
# done downloading  34
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/035.jpg
# done downloading  35
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/036.jpg
# done downloading  36
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/037.jpg
# done downloading  37
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/038.jpg
# done downloading  38
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/039.jpg
# done downloading  39
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/040.jpg
# done downloading  40
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/041.jpg
# done downloading  41
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/042.jpg
# done downloading  42
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/043.jpg
# done downloading  43
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/044.jpg
# done downloading  44
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/045.jpg
# done downloading  45
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/046.jpg
# done downloading  46
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/047.jpg
# done downloading  47
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/048.jpg
# done downloading  48
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/049.jpg
# done downloading  49
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/050.jpg
# done downloading  50
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/051.jpg
# done downloading  51
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/052.jpg
# done downloading  52
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/053.jpg
# done downloading  53
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/054.jpg
# done downloading  54
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/055.jpg
# done downloading  55
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/056.jpg
# done downloading  56
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/057.jpg
# done downloading  57
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/058.jpg
# done downloading  58
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/059.jpg
# done downloading  59
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/060.jpg
# done downloading  60
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/061.jpg
# done downloading  61
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/062.jpg
# done downloading  62
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/063.jpg
# done downloading  63
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/064.jpg
# done downloading  64
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/065.jpg
# done downloading  65
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/066.jpg
# done downloading  66
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/067.jpg
# done downloading  67
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/068.jpg
# done downloading  68
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/069.jpg
# done downloading  69
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/070.jpg
# done downloading  70
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/071.jpg
# done downloading  71
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/072.jpg
# done downloading  72
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/073.jpg
# done downloading  73
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/074.jpg
# done downloading  74
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/075.jpg
# done downloading  75
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/076.jpg
# done downloading  76
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/077.jpg
# done downloading  77
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/078.jpg
# done downloading  78
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/079.jpg
# done downloading  79
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/080.jpg
# done downloading  80
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/081.jpg
# done downloading  81
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/082.jpg
# done downloading  82
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/083.jpg
# done downloading  83
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/084.jpg
# done downloading  84
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/085.jpg
# done downloading  85
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/086.jpg
# done downloading  86
# test
# https://static.yiffer.xyz/comics/First%20Class%20Entertainment/087.jpg
# execution complete
